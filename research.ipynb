# %%
import numpy as np
import pandas as pd

import tensorflow as tf

# %%
df = pd.read_csv('data/motion_with_labess.csv')

# %%
df.head()
# Out:
#             time  acceleration_x  acceleration_y  acceleration_z    gyro_x  \
# 0  1490688591890       -0.064093        0.000000        9.984922 -0.002443
# 1  1490688591900       -0.046603        0.006812        9.992656 -0.002443
# 2  1490688591910       -0.051853        0.029896        9.991413 -0.002443
# 3  1490688591920       -0.043986        0.051782        9.988609 -0.002443
# 4  1490688591930       -0.045143        0.036954       10.015951 -0.002443
#
#    gyro_y    gyro_z  magnetometer_x  magnetometer_y  magnetometer_z  \
# 0     0.0 -0.002443        8.437500       13.449426      -44.177120
# 1     0.0 -0.002443        8.437500       13.323788      -43.957254
# 2     0.0 -0.002443        8.666904       13.369851      -43.937500
# 3     0.0 -0.002443        8.918953       13.432863      -43.937500
# 4     0.0 -0.002443        9.023718       13.494979      -44.023718
#
#       pressure  coarse
# 0  1012.894281       0
# 1  1012.894692       0
# 2  1012.902426       0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('coarse', axis=1)
y = df['coarse']

# %%
X.drop('time', inplace=True, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False)

# %%
X_val, X_test, y_val, y_test = train_test_split(X_train, y_train, test_size=0.5, shuffle=False)

# %%
len(X_train), len(X_test), len(X_val)
# Out:
# (5994586, 2997293, 2997293)

# %%
deviations = X_train.std()
means = X_train.mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 6))
sns.histplot(y_train, ax=axes[0])
sns.histplot(y_val, ax=axes[1])
sns.histplot(y_test, ax=axes[2])
# Out:
# <Axes: xlabel='coarse', ylabel='Count'>

# %%
y_train.value_counts(), y_val.value_counts(), y_test.value_counts()
# Out:
# (coarse
#  8    1659350
#  0    1219139
#  7    1183557
#  2     794257
#  1     587838
#  4     298484
#  6     251961
#  Name: count, dtype: int64,
#  coarse
#  8    1095200
#  7     601819
#  0     521848
#  2     400413
#  1     332973
#  6      45040
#  Name: count, dtype: int64,
#  coarse
#  0    697291
#  7    581738
#  8    564150
#  2    393844
#  4    298484
#  1    254865
#  6    206921
#  Name: count, dtype: int64)

# %%
sns.histplot(y)
# Out:
# <Axes: xlabel='coarse', ylabel='Count'>

# %%
X_train.to_csv('data/pipline_test/X_train.csv')
X_val.to_csv('data/pipline_test/X_val.csv')
X_test.to_csv('data/pipline_test/X_test.csv')

y_train.to_csv('data/pipline_test/y_train.csv')
y_val.to_csv('data/pipline_test/y_val.csv')
y_test.to_csv('data/pipline_test/y_test.csv')

# %%
from models.TCMH import TCMH
import config

# %%
model = TCMH(input_shape=config.INPUT_SHAPE)

# %%
model.summary()
# Out:
# Model: "tcmh"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ...

# %%
model.build(input_shape=[tf.TensorShape((500, 1)) for _ in range(10)])
model.summary()
# Out:
# /Users/timurkaftaranov/Desktop/venvs/neural_networks/lib/python3.12/site-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'tcmh', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model: "tcmh"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ...

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.build(input_shape=[tf.TensorShape((500, 1)) for _ in range(10)])
model.summary()
# Out:
# Model: "tcmh"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ ?                      │   0 (unbuilt) │
# ...

# %%
generator = pd.read_csv('data/pipline_test/X_test.csv', chunksize=config.BATCH_SIZE)

# %%
chunk = next(generator)

# %%
chunk
# Out:
#     Unnamed: 0  acceleration_x  acceleration_y  acceleration_z    gyro_x  \
# 0      2997293        0.298443        2.522027       -9.334262 -0.005797
# 1      2997294        0.288851        2.544337       -9.361477  0.000016
# 2      2997295        0.247233        2.579488       -9.382146  0.020769
# 3      2997296        0.287599        2.585738       -9.417390  0.020769
# 4      2997297        0.288867        2.577724       -9.487689  0.018253
# 5      2997298        0.351556        2.608287       -9.524287  0.015882
# 6      2997299        0.436043        2.662551       -9.512895  0.016042
# 7      2997300        0.466173        2.696023       -9.485675  0.019420
# 8      2997301        0.429192        2.724702       -9.489053  0.028465
# 9      2997302        0.445471        2.761512       -9.498647  0.035433
# 10     2997303        0.490180        2.783725       -9.508206  0.039061
# 11     2997304        0.554142        2.818936       -9.525812  0.037884
# ...
